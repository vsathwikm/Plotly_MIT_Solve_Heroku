# %%
import pandas as pd 
file_loc = "../solver_partner_weights.csv"
data_df = pd.read_csv(file_loc)
# data_df = data_df.drop(columns=['Unnamed: 0'])

# %%
data_df.head()
# Out:
#                                                Org_y  \
# 0                                 Aditya Birla Group
# 1                      BMW Foundation Herbert Quandt
# 2  Buenos Aires Innovation Park (City of Buenos A...
# 3                          C L Sandberg & Associates
# 4                                        Capital One
#
#                           solver  geo_weights  challenge_weights  \
# 0  AIR-INK: Air-Pollution to ink            1                  1
# 1  AIR-INK: Air-Pollution to ink            1                  1
# 2  AIR-INK: Air-Pollution to ink            1                  1
# 3  AIR-INK: Air-Pollution to ink            1                  1
# 4  AIR-INK: Air-Pollution to ink            1                  1
#
#    needs_weights  stage_weights
# 0              1              1
# 1              1              1
# 2              1              1
# 3              1              1
# 4              1              1

# %%
# unpivoted_inital_table = pd.melt(data_df, id_vars="Org_y")
# zero_column = unpivoted_inital_table['value']
# unpivoted_inital_table = unpivoted_inital_table.assign(geo_score=zero_column, 
#                              challenge_score=zero_column,
#                              needs_score=zero_column, 
#                              stage_score=zero_column)
# partners_solvers_weights =  unpivoted_inital_table.drop(columns='value')

# %%
# partners_solvers_weights = partners_solvers_weights.rename(columns={"variable":"solver"})

# %%
# partners_solvers_weights.to_csv("part")

# %%
total_score = pd.read_excel("../outputs/total_score_from_upload.xlsx")
total_score
# Out:
#                                                 Org_y  \
# 0                                  Aditya Birla Group
# 1                       BMW Foundation Herbert Quandt
# 2   Buenos Aires Innovation Park (City of Buenos A...
# 3                           C L Sandberg & Associates
# 4                                               111.0
# 5                                       Classroom Inc
# 6                                     Corning Capital
# 7                                        Covestro LLC
# 8                                DIGITAL CITIZEN FUND
# 9                                             Danaher
# 10                  Draper Richards Kaplan Foundation
# 11                                         Fannie Mae
# 12                         Gary Community Investments
# 13                                      Grupo Salinas
# 14                   Heart Institute of the Caribbean
# 15                                             Henkel
# 16                              Henkel (Charles Paul)
# 17                                         IMPACT2030
# 18                                  Innovation Norway
# 19                                         KSF Impact
# 20                                    Kevin Przybocki
# 21                                          LLamasoft
# 22                                    MIT (Ken Zolot)
# 23  MIT Environmental Solutions Initative (John Fe...
# 24                       MIT Governance Lab (GOV/LAB)
# 25                               Mannin Research Inc.
# 26             Maria Cecilia Souto Vidigal Foundation
# 27                                            Miniwiz
# 28                      New Orleans Health Department
# 29                       Northrop Grumman Corporation
# 30                                  Putnam Associates
# 31                     Robert Wood Johnson Foundation
# 32                                  Save the Children
# 33                 Schmidt Marine Technology Partners
# 34                                              Sitra
# 35                              Terranova Corporation
# 36   The Kroger Co. Zero Hunger Zero Waste Foundation
# 37                     The Pershing Square Foundation
# 38                                               Uber
# 39                                        Yum! Brands
#
#     AIR-INK: Air-Pollution to ink  Aira  \
# 0                             110   111
# 1                              10   110
# 2                              10    10
# 3                              11    10
# 4                             111   111
# 5                             110   110
# 6                             110   111
# 7                             110   110
# 8                              11    10
# 9                             110   110
# 10                             10    11
# 11                            111   110
# 12                            110   111
# 13                             10    10
# 14                             10    10
# 15                            111    11
# 16                            110    11
# 17                            110   110
# 18                             10    11
# 19                             10    11
# 20                            110    11
# 21                             11    10
# 22                             10    10
# 23                            211    10
# 24                             10    10
# 25                             11   111
# 26                            110    10
# 27                            111   110
# 28                            110   110
# 29                             11   110
# 30                            210   110
# 31                            110   110
# 32                            210   110
# 33                            210    11
# 34                             10    10
# 35                            110   110
# 36                            110    11
# 37                            110    10
# 38                             10   110
# 39                             10    10
#
#     Algramo-Catalyzing Reusable Packaging  BioCellection  Blue Sky Analytics  \
# 0                                      11             11                  11
# 1                                      11             10                  10
# 2                                      10             11                  11
# 3                                      11             12                  12
# 4                                     111            111                 111
# 5                                      11             12                  12
# 6                                      10             11                  11
# 7                                      11             11                  11
# 8                                      10             11                  11
# 9                                      11            110                  11
# 10                                     11             12                  12
# 11                                     10            111                  11
# 12                                     11            111                  11
# 13                                    110             12                  11
# 14                                    111             11                  11
# 15                                     11            113                  13
# 16                                     11            111                  12
# 17                                    111            111                  12
# 18                                     11             11                  12
# 19                                    111             10                  11
# 20                                    111            111                  11
# 21                                     11            112                 112
# 22                                     11             11                  11
# 23                                    110            111                 111
# 24                                     11             10                  10
# 25                                     11             12                  12
# 26                                    110            111                  11
# 27                                     10            112                  11
# 28                                     10            113                  14
# 29                                     10             11                  11
# 30                                     11             11                  12
# 31                                     11             11                  11
# 32                                    110             11                  10
# 33                                    111            110                 111
# 34                                     11             10                  11
# 35                                    110             10                  10
# 36                                     10            110                  10
# 37                                    111             10                  11
# 38                                     10             13                  14
# 39                                     11            111                  12
#
#     CareMother  Dost Education  EarlyBird  Elpis Solar  ...  RevelaGov  \
# 0           12              11         10           12  ...         12
# 1           11              10         10           11  ...         10
# 2           11              10         11           10  ...         11
# 3           12              12         10           12  ...         13
# 4          111             111        111          111  ...        111
# 5           12              11         11           11  ...         12
# 6           12              11         11           11  ...         12
# 7           11              11         10           11  ...         11
# 8           11              11         10           11  ...         11
# 9           11              11        110          110  ...         11
# 10          13              12         12          112  ...         14
# 11          11              12        110           11  ...         11
# 12          12              11        110           12  ...         13
# 13          11              11         11           11  ...         11
# 14          11              11         10           11  ...         12
# 15          14              14        112          113  ...         10
# 16          13              10        111           11  ...         14
# 17          12              11        111          110  ...        113
# 18          13              10         11          111  ...         13
# 19          12              10         10           11  ...         12
# 20          12              13        111           12  ...        113
# 21          12             112        110          212  ...        112
# 22          11              11         10           11  ...         12
# 23         111             113        111          211  ...        112
# 24          11              11         10          111  ...        110
# 25          13              12         10           13  ...         14
# 26          11              11        111           10  ...        112
# 27          11              13        110          112  ...         12
# 28          12              13        110           13  ...         11
# 29          11              11         10           11  ...         11
# 30         112              11         11           10  ...         12
# 31          11              12         10           11  ...         11
# 32         110              11         10           11  ...         10
# 33         112             111        110          211  ...        112
# 34          11              11         11          210  ...         12
# 35          10              10         10           10  ...         11
# 36          11              10        110           11  ...         11
# 37          11              12         11           10  ...         12
# 38          12              13         10           13  ...         11
# 39          12              11        112          110  ...         13
#
#     Rheaply  Salauno: Eye care for all  Shape-Up  Supercivicos app  \
# 0       111                         12        11                12
# 1        11                         10        10                10
# 2        10                         11        10                10
# 3        11                         12       111                13
# 4       111                        111       111               111
# 5       111                         12        11                12
# 6       110                         13        10                10
# 7       111                         11        11                12
# 8        10                         11        10                11
# 9       110                         12       110                11
# 10       11                         13        11                12
# 11      110                         12        10                11
# 12      111                         12       111                12
# 13       11                        111        11                11
# 14       11                        111        11                12
# 15      111                         10        11                13
# 16      110                         13       110                11
# 17      110                        113       110               111
# 18       10                         13        10                11
# 19       10                        112        10                11
# 20      111                        113       111               112
# 21       11                         12       111               113
# 22       11                         11       111                12
# 23      110                        112       110               111
# 24       11                         11        10               110
# 25       11                         13        11                13
# 26      110                        112        10               110
# 27      111                         12        11                12
# 28      110                         11        10                14
# 29       10                         11        10                11
# 30      110                         13        10                11
# 31      111                         12        11                12
# 32      111                        110        11                11
# 33      110                        113       110               111
# 34       10                         11        10                11
# 35      110                        110        10                10
# 36      110                         11       110                10
# 37      110                        112        10                11
# 38       10                         11        10                14
# 39       10                         12       110                11
#
#     Tabshoura Tiny Thinkers  The Future is Offline  WheeLog!  Xilinat  \
# 0                        11                     12        13       12
# 1                        10                     10        10       11
# 2                        10                     10        10       10
# 3                        11                     12        13       12
# 4                       111                    111       111      111
# 5                        11                     11        12       11
# 6                        10                     12        11       12
# 7                        11                     11        12       11
# 8                        10                     11        11       10
# 9                        11                     11        11       12
# 10                       11                     12        13       13
# 11                       10                     12        11       11
# 12                       11                     12        13       13
# 13                       10                     11        11       10
# 14                       11                     11        12       12
# 15                       11                     14        14       14
# 16                       11                     11        12       13
# 17                      111                    111        11      113
# 18                       11                     11        12       12
# 19                       11                     11        12       12
# 20                       11                     13        13      114
# 21                       11                     12       113      111
# 22                       11                     11        12       12
# 23                      110                    112       111      112
# 24                       10                     11        10      112
# 25                       11                     13        14       13
# 26                       10                     11       110      112
# 27                       10                     13        12       12
# 28                       10                     13        12       11
# 29                       10                     11        11       10
# 30                       11                     11        11       12
# 31                       11                     12        12       12
# 32                      110                    111        11       10
# 33                      111                    112       112      113
# 34                      111                    110        11       12
# 35                       10                     10        10       11
# 36                       10                     11        11       11
# 37                       11                     11        11       13
# 38                       10                     13        12       11
# 39                       11                     10       111       12
#
#     change:WATER Labs' iThrone: a waste-shrinking toilet
# 0                                                  12
# 1                                                  10
# 2                                                  10
# 3                                                  12
# 4                                                 111
# 5                                                  11
# 6                                                  11
# 7                                                  11
# 8                                                  11
# 9                                                 111
# 10                                                 12
# 11                                                 11
# 12                                                 12
# 13                                                 10
# 14                                                 11
# 15                                                 13
# 16                                                 12
# 17                                                111
# 18                                                 12
# 19                                                 12
# 20                                                 12
# 21                                                112
# 22                                                 11
# 23                                                111
# 24                                                110
# 25                                                 13
# 26                                                 10
# 27                                                 11
# 28                                                 14
# 29                                                 11
# 30                                                 11
# 31                                                 11
# 32                                                 10
# 33                                                112
# 34                                                 11
# 35                                                 10
# 36                                                 11
# 37                                                 11
# 38                                                 14
# 39                                                 11
#
# [40 rows x 33 columns]

# %%
total_score['Aira'][(total_score['Org_y'] == "Aditya Birla Group")] = 1233.0
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
total_score.head()
# Out:
#                                                Org_y  \
# 0                                 Aditya Birla Group
# 1                      BMW Foundation Herbert Quandt
# 2  Buenos Aires Innovation Park (City of Buenos A...
# 3                          C L Sandberg & Associates
# 4                                              111.0
#
#    AIR-INK: Air-Pollution to ink  Aira  Algramo-Catalyzing Reusable Packaging  \
# 0                            110  1233                                     11
# 1                             10   110                                     11
# 2                             10    10                                     10
# 3                             11    10                                     11
# 4                            111   111                                    111
#
#    BioCellection  Blue Sky Analytics  CareMother  Dost Education  EarlyBird  \
# 0             11                  11          12              11         10
# 1             10                  10          11              10         10
# 2             11                  11          11              10         11
# 3             12                  12          12              12         10
# 4            111                 111         111             111        111
#
#    Elpis Solar  ...  RevelaGov  Rheaply  Salauno: Eye care for all  Shape-Up  \
# 0           12  ...         12      111                         12        11
# 1           11  ...         10       11                         10        10
# 2           10  ...         11       10                         11        10
# 3           12  ...         13       11                         12       111
# 4          111  ...        111      111                        111       111
#
#    Supercivicos app  Tabshoura Tiny Thinkers  The Future is Offline  WheeLog!  \
# 0                12                       11                     12        13
# 1                10                       10                     10        10
# 2                10                       10                     10        10
# 3                13                       11                     12        13
# 4               111                      111                    111       111
#
#    Xilinat  change:WATER Labs' iThrone: a waste-shrinking toilet
# 0       12                                                 12
# 1       11                                                 10
# 2       10                                                 10
# 3       12                                                 12
# 4      111                                                111
#
# [5 rows x 33 columns]

# %%
partner_solver_weights = pd.read_csv("../solver_partner_weights.csv")
sw = 3 
nw = 2
gw = 5
cw = 4
partner_name = "Capital One"
solver_name = "Aira"
partner_solver_weights[(partner_solver_weights['solver'] == solver_name) & (partner_solver_weights['Org_y'] == partner_name)]['geo_weights'] = gw
# partner_solver_weights[(partner_solver_weights['solver'] == solver_name) & (partner_solver_weights['Org_y'] == partner_name)]['needs_weights'] = nw
# partner_solver_weights[(partner_solver_weights['solver'] == solver_name) & (partner_solver_weights['Org_y'] == partner_name)]['challenge_weights'] = cw
# partner_solver_weights[(partner_solver_weights['solver'] == solver_name) & (partner_solver_weights['Org_y'] == partner_name)]['stage_weights'] = sw
# partner_solver_weights.to_csv("solver_partner_weights.csv")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# partner_solver_weights[partner_solver_weights['solver'] == "Aira"]
partner_solver_weights[(partner_solver_weights['solver'] == solver_name) & (partner_solver_weights['Org_y'] == partner_name)]['geo_weights'] = 34
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
row_index = partner_solver_weights[(partner_solver_weights['solver'] == solver_name) & (partner_solver_weights['Org_y'] == partner_name)].index
partner_solver_weights.loc[44, 'geo_weights'] =  34

# %%
partner_solver_weights[(partner_solver_weights['solver'] == solver_name) & (partner_solver_weights['Org_y'] == partner_name)]
# Out:
#           Org_y solver  geo_weights  challenge_weights  needs_weights  \
# 44  Capital One   Aira           34                  1              1
#
#     stage_weights
# 44              1
