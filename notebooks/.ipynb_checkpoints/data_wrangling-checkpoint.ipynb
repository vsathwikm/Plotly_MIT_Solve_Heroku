# %%
import pandas as pd 
file_loc = "../solver_partner_weights.csv"
data_df = pd.read_csv(file_loc)
# data_df = data_df.drop(columns=['Unnamed: 0'])

# %%
data_df.head()
# Out:
#                                                Org_y  \
# 0                                 Aditya Birla Group
# 1                      BMW Foundation Herbert Quandt
# 2  Buenos Aires Innovation Park (City of Buenos A...
# 3                          C L Sandberg & Associates
# 4                                        Capital One
#
#                           solver  geo_weights  challenge_weights  \
# 0  AIR-INK: Air-Pollution to ink            1                  1
# 1  AIR-INK: Air-Pollution to ink            1                  1
# 2  AIR-INK: Air-Pollution to ink            1                  1
# 3  AIR-INK: Air-Pollution to ink            1                  1
# 4  AIR-INK: Air-Pollution to ink            1                  1
#
#    needs_weights  stage_weights
# 0            1.0              1
# 1            1.0              1
# 2            1.0              1
# 3            1.0              1
# 4            4.0              1

# %%
# unpivoted_inital_table = pd.melt(data_df, id_vars="Org_y")
# zero_column = unpivoted_inital_table['value']
# unpivoted_inital_table = unpivoted_inital_table.assign(geo_score=zero_column, 
#                              challenge_score=zero_column,
#                              needs_score=zero_column, 
#                              stage_score=zero_column)
# partners_solvers_weights =  unpivoted_inital_table.drop(columns='value')

# %%
# partners_solvers_weights = partners_solvers_weights.rename(columns={"variable":"solver"})

# %%
# partners_solvers_weights.to_csv("part")

# %%
# total_score = pd.read_excel("../outputs/total_score_from_upload.xlsx")
# total_score

# %%
total_score['Aira'][(total_score['Org_y'] == "Aditya Birla Group")] = 1233.0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-6a2ceb5e6ea8> in <module>
# ----> 1 total_score['Aira'][(total_score['Org_y'] == "Aditya Birla Group")] = 1233.0
#
# NameError: name 'total_score' is not defined

# %%
total_score.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-eff175afbd0a> in <module>
# ----> 1 total_score.head()
#
# NameError: name 'total_score' is not defined

# %%
partner_solver_weights = pd.read_csv("../solver_partner_weights.csv")
sw = 3 
nw = 2
gw = 5
cw = 4
partner_name = "Capital One"
solver_name = "Aira"
partner_solver_weights[(partner_solver_weights['solver'] == solver_name) & (partner_solver_weights['Org_y'] == partner_name)]['geo_weights'] = gw
# partner_solver_weights[(partner_solver_weights['solver'] == solver_name) & (partner_solver_weights['Org_y'] == partner_name)]['needs_weights'] = nw
# partner_solver_weights[(partner_solver_weights['solver'] == solver_name) & (partner_solver_weights['Org_y'] == partner_name)]['challenge_weights'] = cw
# partner_solver_weights[(partner_solver_weights['solver'] == solver_name) & (partner_solver_weights['Org_y'] == partner_name)]['stage_weights'] = sw
# partner_solver_weights.to_csv("solver_partner_weights.csv")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# partner_solver_weights[partner_solver_weights['solver'] == "Aira"]
partner_solver_weights[(partner_solver_weights['solver'] == solver_name) & (partner_solver_weights['Org_y'] == partner_name)]['geo_weights'] = 34
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
row_index = partner_solver_weights[(partner_solver_weights['solver'] == solver_name) & (partner_solver_weights['Org_y'] == partner_name)].index
partner_solver_weights.loc[44, 'geo_weights'] =  34

# %%
partner_solver_weights[(partner_solver_weights['solver'] == solver_name) & (partner_solver_weights['Org_y'] == partner_name)]['challenge_weights'].values[0]
# Out:
# 1

# %%
geo_weights_pivot = pd.pivot(partner_solver_weights[['Org_y', 'solver', 'geo_weights']], columns='solver', index='Org_y' )
needs_weights_pivot = pd.pivot(partner_solver_weights[['Org_y', 'solver', 'needs_weights']], columns='solver', index='Org_y' )
challenge_weights_pivot = pd.pivot(partner_solver_weights[['Org_y', 'solver', 'challenge_weights']], columns='solver', index='Org_y' )
stage_weights_pivot = pd.pivot(partner_solver_weights[['Org_y', 'solver', 'stage_weights']], columns='solver', index='Org_y' )

# %%
import zebra
export_path = "../outputs/"
# print("total score export_path: ", export_path)
# Mentor data
partners_df = zebra.csv_to_df(export_path+"partner_data.csv")
# filled nan with 0 
partners_df = partners_df.fillna(0)
type(partners_df["Org"])

# Solver data
solver_df = zebra.csv_to_df(export_path+"solver_team_data.csv")
# filled nan with 0 
solver_df = solver_df.fillna(0)

# Get geo choice for solver
solver_geo = zebra.solver_geo_df(solver_df)

# Get geo choices for partner
partners_geo = zebra.partner_geo_df(partners_df)

# Generate geo contingency table
unpivoted_solver_geo = zebra.solver_regions_listform(solver_geo, solver_df)

# Generate pivot table
_,geo_pivot_copy = zebra.pivot_table_geo(unpivoted_solver_geo,partners_geo, export_path, export=False)

# Get needs for Partners
partners_needs = zebra.get_partners_needs(partners_df)

# Get needs for Solveras
unpivoted_solver_needs= zebra.get_solver_needs(solver_df)

# Read in partner pivot table
needs_values, needs_pivot_copy = zebra.pivot_table_needs(unpivoted_solver_needs,partners_needs, export_path, export=False)

# Get Partner Challenges
ch_partners_challenges = zebra.get_ch_partners(partners_df)

# Get Solver Challenges
ch_solver = zebra.get_ch_solvers(solver_df)

# Generate pivot table
challenges_pivot, challenges_pivot_copy = zebra.pivot_table_challenges(ch_solver, ch_partners_challenges, export_path, export=False)

# Get Parter stage data
st_partners = zebra.get_st_partners(partners_df)

# Get Solver statge data
st_solver = zebra.get_st_solver(solver_df)

# Generate pivot table
_,stage_pivot_copy = zebra.pivot_table_stage(st_solver, st_partners, export_path, export=False)

needs_pivot_copy = needs_pivot_copy.rename_axis('solver', axis="columns")
geo_pivot_copy = needs_pivot_copy.rename_axis('solver', axis="columns")
stage_pivot_copy = needs_pivot_copy.rename_axis('solver', axis="columns")
challenge_pivot_copy = needs_pivot_copy.rename_axis('solver', axis="columns")

geo_term  =  geo_weights_pivot.multiply(geo_pivot_copy.astype(float), axis=0)
stage_term  =  stage_weights_pivot.multiply(stage_pivot_copy.astype(float), axis=0)
geo_stage_term = geo_term.multiply(stage_term, axis=0)
needs_term = needs_weights_pivot.multiply(needs_pivot_copy.astype(float), axis=0)
challenge_term = challenge_weights_pivot.multiply(challenge_pivot_copy.astype(float), axis=0)

# Combine all of the answers
total_score = geo_stage_term + challenge_term + needs_term
# Out:
# D:\Data_science\colaberry\Plotly_MIT_Solve_Heroku\notebooks\zebra.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ch_partners["Challenge Preference"] =  ch_partners["Challenge Preference"].str.split(",")
# D:\Data_science\colaberry\Plotly_MIT_Solve_Heroku\notebooks\zebra.py:331: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   st_partners["Stage"] = st_partners["Solution Preference: Organization Stage"].str.strip()
# D:\Data_science\colaberry\Plotly_MIT_Solve_Heroku\notebooks\zebra.py:332: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   st_partners["Stage"] = st_partners["Stage"].str.split(",")
# D:\Data_science\colaberry\Plotly_MIT_Solve_Heroku\notebooks\zebra.py:349: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   st_solver["Stage"] = st_solver["Stage"].str.strip()

# %%
# Out:
# ((40, 32), (40, 32))

# %%
needs_weights_pivot.index == needs_pivot_copy.index
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True])

# %%
needs_weights_pivot.head()
# Out:
#                                                                    needs_weights  \
# solver                                             AIR-INK: Air-Pollution to ink
# Org_y
# Aditya Birla Group                                                           1.0
# BMW Foundation Herbert Quandt                                                1.0
# Buenos Aires Innovation Park (City of Buenos Ai...                           1.0
# C L Sandberg & Associates                                                    1.0
# Capital One                                                                  4.0
#
#                                                          \
# solver                                             Aira
# Org_y
# Aditya Birla Group                                  1.0
# BMW Foundation Herbert Quandt                       1.0
# Buenos Aires Innovation Park (City of Buenos Ai...  1.0
# C L Sandberg & Associates                           1.0
# Capital One                                         1.0
#
#                                                                                           \
# solver                                             Algramo-Catalyzing Reusable Packaging
# Org_y
# Aditya Birla Group                                                                   1.0
# BMW Foundation Herbert Quandt                                                        1.0
# Buenos Aires Innovation Park (City of Buenos Ai...                                   1.0
# C L Sandberg & Associates                                                            1.0
# Capital One                                                                          1.0
#
#                                                                   \
# solver                                             BioCellection
# Org_y
# Aditya Birla Group                                           1.0
# BMW Foundation Herbert Quandt                                1.0
# Buenos Aires Innovation Park (City of Buenos Ai...           1.0
# C L Sandberg & Associates                                    1.0
# Capital One                                                  1.0
#
#                                                                        \
# solver                                             Blue Sky Analytics
# Org_y
# Aditya Birla Group                                                1.0
# BMW Foundation Herbert Quandt                                     1.0
# Buenos Aires Innovation Park (City of Buenos Ai...                1.0
# C L Sandberg & Associates                                         1.0
# Capital One                                                       1.0
#
#                                                                               \
# solver                                             CareMother Dost Education
# Org_y
# Aditya Birla Group                                        1.0            1.0
# BMW Foundation Herbert Quandt                             1.0            1.0
# Buenos Aires Innovation Park (City of Buenos Ai...        1.0            1.0
# C L Sandberg & Associates                                 1.0            1.0
# Capital One                                               1.0            1.0
#
#                                                                           \
# solver                                             EarlyBird Elpis Solar
# Org_y
# Aditya Birla Group                                       1.0         1.0
# BMW Foundation Herbert Quandt                            1.0         1.0
# Buenos Aires Innovation Park (City of Buenos Ai...       1.0         1.0
# C L Sandberg & Associates                                1.0         1.0
# Capital One                                              1.0         1.0
#
#                                                                         ...  \
# solver                                             Faircap Clean Water  ...
# Org_y                                                                   ...
# Aditya Birla Group                                                 1.0  ...
# BMW Foundation Herbert Quandt                                      1.0  ...
# Buenos Aires Innovation Park (City of Buenos Ai...                 1.0  ...
# C L Sandberg & Associates                                          1.0  ...
# Capital One                                                        1.0  ...
#
#                                                                       \
# solver                                             RevelaGov Rheaply
# Org_y
# Aditya Birla Group                                       1.0     1.0
# BMW Foundation Herbert Quandt                            1.0     1.0
# Buenos Aires Innovation Park (City of Buenos Ai...       1.0     1.0
# C L Sandberg & Associates                                1.0     1.0
# Capital One                                              1.0     1.0
#
#                                                                               \
# solver                                             Salauno: Eye care for all
# Org_y
# Aditya Birla Group                                                       1.0
# BMW Foundation Herbert Quandt                                            1.0
# Buenos Aires Innovation Park (City of Buenos Ai...                       1.0
# C L Sandberg & Associates                                                1.0
# Capital One                                                              1.0
#
#                                                                               \
# solver                                             Shape-Up Supercivicos app
# Org_y
# Aditya Birla Group                                      1.0              1.0
# BMW Foundation Herbert Quandt                           1.0              1.0
# Buenos Aires Innovation Park (City of Buenos Ai...      1.0              1.0
# C L Sandberg & Associates                               1.0              1.0
# Capital One                                             1.0              1.0
#
#                                                                             \
# solver                                             Tabshoura Tiny Thinkers
# Org_y
# Aditya Birla Group                                                     1.0
# BMW Foundation Herbert Quandt                                          1.0
# Buenos Aires Innovation Park (City of Buenos Ai...                     1.0
# C L Sandberg & Associates                                              1.0
# Capital One                                                            1.0
#
#                                                                           \
# solver                                             The Future is Offline
# Org_y
# Aditya Birla Group                                                   1.0
# BMW Foundation Herbert Quandt                                        1.0
# Buenos Aires Innovation Park (City of Buenos Ai...                   1.0
# C L Sandberg & Associates                                            1.0
# Capital One                                                          1.0
#
#                                                                      \
# solver                                             WheeLog! Xilinat
# Org_y
# Aditya Birla Group                                      1.0     1.0
# BMW Foundation Herbert Quandt                           1.0     1.0
# Buenos Aires Innovation Park (City of Buenos Ai...      1.0     1.0
# C L Sandberg & Associates                               1.0     1.0
# Capital One                                             1.0     1.0
#
#
# solver                                             change:WATER Labs' iThrone: a waste-shrinking toilet
# Org_y
# Aditya Birla Group                                                                                1.0
# BMW Foundation Herbert Quandt                                                                     1.0
# Buenos Aires Innovation Park (City of Buenos Ai...                                                1.0
# C L Sandberg & Associates                                                                         1.0
# Capital One                                                                                       1.0
#
# [5 rows x 32 columns]

# %%
needs_pivot_copy.head()
# Out:
# Org_x                                               AIR-INK: Air-Pollution to ink  \
# Org_y
# Aditya Birla Group                                                              0
# BMW Foundation Herbert Quandt                                                   0
# Buenos Aires Innovation Park (City of Buenos Ai...                              0
# C L Sandberg & Associates                                                       1
# Capital One                                                                     1
#
# Org_x                                               Aira  \
# Org_y
# Aditya Birla Group                                     1
# BMW Foundation Herbert Quandt                          0
# Buenos Aires Innovation Park (City of Buenos Ai...     0
# C L Sandberg & Associates                              0
# Capital One                                            0
#
# Org_x                                               Algramo-Catalyzing Reusable Packaging  \
# Org_y
# Aditya Birla Group                                                                      1
# BMW Foundation Herbert Quandt                                                           1
# Buenos Aires Innovation Park (City of Buenos Ai...                                      0
# C L Sandberg & Associates                                                               1
# Capital One                                                                             1
#
# Org_x                                               BioCellection  \
# Org_y
# Aditya Birla Group                                              1
# BMW Foundation Herbert Quandt                                   0
# Buenos Aires Innovation Park (City of Buenos Ai...              1
# C L Sandberg & Associates                                       2
# Capital One                                                     3
#
# Org_x                                               Blue Sky Analytics  \
# Org_y
# Aditya Birla Group                                                   1
# BMW Foundation Herbert Quandt                                        0
# Buenos Aires Innovation Park (City of Buenos Ai...                   1
# C L Sandberg & Associates                                            2
# Capital One                                                          3
#
# Org_x                                               CareMother  \
# Org_y
# Aditya Birla Group                                           2
# BMW Foundation Herbert Quandt                                1
# Buenos Aires Innovation Park (City of Buenos Ai...           1
# C L Sandberg & Associates                                    2
# Capital One                                                  3
#
# Org_x                                               Dost Education  EarlyBird  \
# Org_y
# Aditya Birla Group                                               1          0
# BMW Foundation Herbert Quandt                                    0          0
# Buenos Aires Innovation Park (City of Buenos Ai...               0          1
# C L Sandberg & Associates                                        2          0
# Capital One                                                      4          2
#
# Org_x                                               Elpis Solar  \
# Org_y
# Aditya Birla Group                                            2
# BMW Foundation Herbert Quandt                                 1
# Buenos Aires Innovation Park (City of Buenos Ai...            0
# C L Sandberg & Associates                                     2
# Capital One                                                   2
#
# Org_x                                               Faircap Clean Water  ...  \
# Org_y                                                                    ...
# Aditya Birla Group                                                    2  ...
# BMW Foundation Herbert Quandt                                         0  ...
# Buenos Aires Innovation Park (City of Buenos Ai...                    0  ...
# C L Sandberg & Associates                                             3  ...
# Capital One                                                           3  ...
#
# Org_x                                               RevelaGov  Rheaply  \
# Org_y
# Aditya Birla Group                                          2        1
# BMW Foundation Herbert Quandt                               0        1
# Buenos Aires Innovation Park (City of Buenos Ai...          1        0
# C L Sandberg & Associates                                   3        1
# Capital One                                                 4        1
#
# Org_x                                               Salauno: Eye care for all  \
# Org_y
# Aditya Birla Group                                                          2
# BMW Foundation Herbert Quandt                                               0
# Buenos Aires Innovation Park (City of Buenos Ai...                          1
# C L Sandberg & Associates                                                   2
# Capital One                                                                 4
#
# Org_x                                               Shape-Up  \
# Org_y
# Aditya Birla Group                                         1
# BMW Foundation Herbert Quandt                              0
# Buenos Aires Innovation Park (City of Buenos Ai...         0
# C L Sandberg & Associates                                  1
# Capital One                                                1
#
# Org_x                                               Supercivicos app  \
# Org_y
# Aditya Birla Group                                                 2
# BMW Foundation Herbert Quandt                                      0
# Buenos Aires Innovation Park (City of Buenos Ai...                 0
# C L Sandberg & Associates                                          3
# Capital One                                                        3
#
# Org_x                                               Tabshoura Tiny Thinkers  \
# Org_y
# Aditya Birla Group                                                        1
# BMW Foundation Herbert Quandt                                             0
# Buenos Aires Innovation Park (City of Buenos Ai...                        0
# C L Sandberg & Associates                                                 1
# Capital One                                                               1
#
# Org_x                                               The Future is Offline  \
# Org_y
# Aditya Birla Group                                                      2
# BMW Foundation Herbert Quandt                                           0
# Buenos Aires Innovation Park (City of Buenos Ai...                      0
# C L Sandberg & Associates                                               2
# Capital One                                                             3
#
# Org_x                                               WheeLog!  Xilinat  \
# Org_y
# Aditya Birla Group                                         3        2
# BMW Foundation Herbert Quandt                              0        1
# Buenos Aires Innovation Park (City of Buenos Ai...         0        0
# C L Sandberg & Associates                                  3        2
# Capital One                                                3        3
#
# Org_x                                               change:WATER Labs' iThrone: a waste-shrinking toilet
# Org_y
# Aditya Birla Group                                                                                  2
# BMW Foundation Herbert Quandt                                                                       0
# Buenos Aires Innovation Park (City of Buenos Ai...                                                  0
# C L Sandberg & Associates                                                                           2
# Capital One                                                                                         2
#
# [5 rows x 32 columns]
